# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import os


# Impor the OpenWeatherMap API key
from api_keys import weather_api_key


# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 597

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Test section
# Define the base URL
# base_url = "https://api.openweathermap.org/data/2.5/weather?"
# city = "London"  # Example city

# city_url = base_url + "appid=" + weather_api_key + "&q=" + city

# Make the API request
# weather_response = requests.get(city_url)
# city_weather = weather_response.json()
# city_weather

# %%
# city_url = base_url + "appid=" + weather_api_key + "&q=" + city
# city_url

# %%
# Set the API base URL - OK
base_url = "https://api.openweathermap.org/data/2.5/weather?"
city = "London"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city - OK
    city_url = base_url + "appid=" + weather_api_key + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        weather_response = requests.get(city_url)
        city_weather = weather_response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']# YOUR CODE HERE coord.lat
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']# YOUR CODE HERE main.temp_max
        city_humidity = city_weather['main']['humidity']# YOUR CODE HERE main.humidity
        city_clouds = city_weather['clouds']['all']# YOUR CODE HERE clouds.all
        city_wind = city_weather['wind']['speed']# YOUR CODE HERE wind.speed default meter/sec
        city_country = city_weather['sys']['country']# YOUR CODE HERE sys.country
        city_date = city_weather['dt'] # YOUR CODE HERE dt

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | olonkinbyen
# Processing Record 2 of Set 1 | el calafate
# Processing Record 3 of Set 1 | mbanza kongo
# Processing Record 4 of Set 1 | egilsstadir
# Processing Record 5 of Set 1 | grytviken
# Processing Record 6 of Set 1 | aqadyr
# Processing Record 7 of Set 1 | adamstown
# Processing Record 8 of Set 1 | longyearbyen
# Processing Record 9 of Set 1 | edinburgh of the seven seas
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | yaren
# Processing Record 12 of Set 1 | palikir - national government center
# Processing Record 13 of Set 1 | labrador city
# Processing Record 14 of Set 1 | port-aux-francais
# Processing Record 15 of Set 1 | fuvahmulah
# City not found. Skipping...
# Processing Record 16 of Set 1 | san patricio
# Processing Record 17 of Set 1 | itaituba
# Processing Record 18 of Set 1 | juneau
# Processing Record 19 of Set 1 | calama
# Processing Record 20 of Set 1 | ust-nera
# Processing Record 21 of Set 1 | sitka
# Processing Record 22 of Set 1 | blackmans bay
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | port-cartier
# Processing Record 25 of Set 1 | east london
# Processing Record 26 of Set 1 | puerto natales
# Processing Record 27 of Set 1 | west island
# Processing Record 28 of Set 1 | bethel
# Processing Record 29 of Set 1 | qaqortoq
# Processing Record 30 of Set 1 | puerto ayora
# Processing Record 31 of Set 1 | malabar
# Processing Record 32 of Set 1 | kabalo
# Processing Record 33 of Set 1 | lagoa
# Processing Record 34 of Set 1 | bodaybo
# Processing Record 35 of Set 1 | whitehorse
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 | isafjordur
# Processing Record 38 of Set 1 | stanley
# Processing Record 39 of Set 1 | stanthorpe
# Processing Record 40 of Set 1 | port elizabeth
# Processing Record 41 of Set 1 | laayoune plage
# City not found. Skipping...
# Processing Record 42 of Set 1 | mangalia
# Processing Record 43 of Set 1 | tura
# Processing Record 44 of Set 1 | xiaoweizhai
# Processing Record 45 of Set 1 | kone
# Processing Record 46 of Set 1 | papao
# Processing Record 47 of Set 1 | queenstown
# Processing Record 48 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record
# Processing Record 48 of Set 4 | opoczno
# Processing Record 49 of Set 4 | uturoa
# Processing Record 0 of Set 5 | sao jose da coroa grande
# Processing Record 1 of Set 5 | twon-brass
# Processing Record 2 of Set 5 | weno
# Processing Record 3 of Set 5 | cayon
# Processing Record 4 of Set 5 | aasiaat
# Processing Record 5 of Set 5 | laguna
# Processing Record 6 of Set 5 | port alfred
# Processing Record 7 of Set 5 | alofi
# Processing Record 8 of Set 5 | santo antonio
# Processing Record 9 of Set 5 | klyuchi
# Processing Record 10 of Set 5 | hoxtolgay
# City not found. Skipping...
# Processing Record 11 of Set 5 | nguigmi
# Processing Record 12 of Set 5 | nchelenge
# Processing Record 13 of Set 5 | sidi ifni
# Processing Record 14 of Set 5 | uvarovo
# Processing Record 15 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 16 of Set 5 | st. john's
# Processing Record 17 of Set 5 | ambalangoda
# Processing Record 18 of Set 5 | camana
# Processing Record 19 of Set 5 | eminabad
# Processing Record 20 of Set 5 | mogocha
# Processing Record 21 of Set 5 | mogadishu
# Processing Record 22 of Set 5 | pickering
# Processing Record 23 of Set 5 | belyayevka
# Processing Record 24 of Set 5 | rancho palos verdes
# Processing Record 25 of Set 5 | pacific grove
# Processing Record 26 of Set 5 | san luis de la loma
# Processing Record 27 of Set 5 | kulia village
# City not found. Skipping...
# Processing Record 28 of Set 5 | orbeasca de sus
# Processing Record 29 of Set 5 | asau village
# City not found. Skipping...
# Processing Record 30 of Set 5 | tazovsky
# Processing Record 31 of Set 5 | slave lake
# Processing Record 32 of Set 5 | madera acres
# Processing Record 33 of Set 5 | tucuma
# Processing Record 34 of Set 5 | nassau
# Processing Record 35 of Set 5 | el porvenir
# Processing Record 36 of Set 5 | taulaga
# Processing Record 37 of Set 5 | saudarkrokur
# Processing Record 38 of Set 5 | darwin
# Processing Record 39 of Set 5 | ust-tsilma
# Processing Record 40 of Set 5 | linares
# Processing Record 41 of Set 5 | pisco
# Processing Record 42 of Set 5 | kyzyl-mazhalyk
# Processing Record 43 of Set 5 | kirakira
# Processing Record 44 of Set 5 | duluth
# Processing Record 45 of Set 5 | kulgam
# Processing Record 46 of Set 5 | ninghai
# Processing Record 47 of Set 5 | sena madureira
# Processing Record 48 of Set 5 | soio
# Processing Record 49 of Set 5 | liwale
# Processing Record 0 of Set 6 | margaret river
# Processing Record 1 of Set 6 | san angelo
# Processing Record 2 of Set 6 | zhanaozen
# Processing Record 3 of Set 6 | lycksele
# Processing Record 4 of Set 6 | san felipe
# Processing Record 5 of Set 6 | lazaro cardenas
# Processing Record 6 of Set 6 | lata
# Processing Record 7 of Set 6 | ouahigouya
# Processing Record 8 of Set 6 | anna regina
# Processing Record 9 of Set 6 | chepelare
# Processing Record 10 of Set 6 | barra do corda
# Processing Record 11 of Set 6 | farasan
# Processing Record 12 of Set 6 | seogwipo
# City not found. Skipping...
# Processing Record 13 of Set 6 | grootfontein
# Processing Record 14 of Set 6 | san-pedro
# Processing Record 15 of Set 6 | kargopol'
# Processing Record 16 of Set 6 | tofol
# Processing Record 17 of Set 6 | i-n-salah
# Processing Record 18 of Set 6 | enewetak
# Processing Record 19 of Set 6 | siguiri
# Processing Record 20 of Set 6 | saint-louis
# Processing Record 21 of Set 6 | ajaccio
# Processing Record 22 of Set 6 | cargados carajos
# City not found. Skipping...
# Processing Record 23 of Set 6 | bubaque
# Processing Record 24 of Set 6 | arraial do cabo
# Processing Record 25 of Set 6 | sierra grande
# Processing Record 26 of Set 6 | esperanza
# Processing Record 27 of Set 6 | hefei
# Processing Record 28 of Set 6 | gillette
# Processing Record 29 of Set 6 | lefkada
# Processing Record 30 of Set 6 | viiala
# Processing Record 31 of Set 6 | al jawf
# Processing Record 32 of Set 6 | labytnangi
# Processing Record 33 of Set 6 | nsanje
# Processing Record 34 of Set 6 | chonchi
# Processing Record 35 of Set 6 | awjilah
# Processing Record 36 of Set 6 | opuwo
# Processing Record 37 of Set 6 | eyl
# Processing Record 38 of Set 6 | nar'yan-mar
# Processing Record 39 of Set 6 | pont rouge
# Processing Record 40 of Set 6 | tranovaho
# City not found. Skipping...
# Processing Record 41 of Set 6 | arkhangel'sk
# Processing Record 42 of Set 6 | pacasmayo
# Processing Record 43 of Set 6 | urucara
# Processing Record 44 of Set 6 | iquique
# Processing Record 45 of Set 6 | atherton
# Processing Record 46 of Set 6 | happy valley-goose bay
# Processing Record 47 of Set 6 | po
# City not found. Skipping...
# Processing Record 48 of Set 6 | mitu
# Processing Record 49 of Set 6 | nkongsamba
# Processing Record 0 of Set 7 | hamilton
# Processing Record 1 of Set 7 | ichihara
# Processing Record 2 of Set 7 | moama
# Processing Record 3 of Set 7 | north bondi
# Processing Record 4 of Set 7 | labuan
# Processing Record 5 of Set 7 | yarkovo
# Processing Record 6 of Set 7 | kailua-kona
# Processing Record 7 of Set 7 | karratha
# Processing Record 8 of Set 7 | la tuque
# Processing Record 9 of Set 7 | idrinskoye
# Processing Record 10 of Set 7 | zemio
# Processing Record 11 of Set 7 | banda aceh
# Processing Record 12 of Set 7 | peace river
# Processing Record 13 of Set 7 | gueltat zemmour
# City not found. Skipping...
# Processing Record 14 of Set 7 | bonthe
# Processing Record 15 of Set 7 | oltinko'l
# Processing Record 16 of Set 7 | nanao
# Processing Record 17 of Set 7 | igarka
# Processing Record 18 of Set 7 | bridgewater
# Processing Record 19 of Set 7 | mersa matruh
# Processing Record 20 of Set 7 | motueka
# Processing Record 21 of Set 7 | port saint john's
# Processing Record 22 of Set 7 | fort st. john
# Processing Record 23 of Set 7 | vila velha
# Processing Record 24 of Set 7 | las heras
# Processing Record 25 of Set 7 | selkirk
# Processing Record 26 of Set 7 | sovetskiy
# Processing Record 27 of Set 7 | codrington
# Processing Record 28 of Set 7 | magadan
# Processing Record 29 of Set 7 | madera
# Processing Record 30 of Set 7 | goba
# Processing Record 31 of Set 7 | nova sintra
# Processing Record 32 of Set 7 | tanrake village
# City not found. Skipping...
# Processing Record 33 of Set 7 | norrkoping
# Processing Record 34 of Set 7 | mount pearl
# Processing Record 35 of Set 7 | xai-xai
# Processing Record 36 of Set 7 | menaka
# Processing Record 37 of Set 7 | elassona
# Processing Record 38 of Set 7 | saint-leu
# Processing Record 39 of Set 7 | shuangjiang
# Processing Record 40 of Set 7 | antofagasta
# Processing Record 41 of Set 7 | belle plaine
# Processing Record 42 of Set 7 | freetown
# Processing Record 13 of Set 9 | tadine
# Processing Record 14 of Set 9 | akdagmadeni
# Processing Record 15 of Set 9 | ridgefield
# Processing Record 16 of Set 9 | petropavlovsk-kamchatsky
# Processing Record 17 of Set 9 | crane
# Processing Record 18 of Set 9 | suntar
# Processing Record 19 of Set 9 | acapulco de juarez
# Processing Record 20 of Set 9 | lompoc
# Processing Record 21 of Set 9 | bengkulu
# Processing Record 22 of Set 9 | grande prairie
# Processing Record 23 of Set 9 | kraljevo
# Processing Record 24 of Set 9 | sur
# Processing Record 25 of Set 9 | mount gambier
# Processing Record 26 of Set 9 | tsiombe
# Processing Record 27 of Set 9 | were ilu
# Processing Record 28 of Set 9 | thinadhoo
# Processing Record 29 of Set 9 | temiskaming shores
# Processing Record 30 of Set 9 | mahina
# Processing Record 31 of Set 9 | willowmore
# Processing Record 32 of Set 9 | atbasar
# Processing Record 33 of Set 9 | island harbour
# Processing Record 34 of Set 9 | nagqu
# Processing Record 35 of Set 9 | banswara
# Processing Record 36 of Set 9 | ilhabela
# Processing Record 37 of Set 9 | konarka
# Processing Record 38 of Set 9 | yuzhno-kurilsk
# Processing Record 39 of Set 9 | la ronge
# Processing Record 40 of Set 9 | muromtsevo
# Processing Record 41 of Set 9 | ijuw
# City not found. Skipping...
# Processing Record 42 of Set 9 | at taj
# Processing Record 43 of Set 9 | lafiagi
# Processing Record 44 of Set 9 | nola
# Processing Record 45 of Set 9 | kodok
# City not found. Skipping...
# Processing Record 46 of Set 9 | mugia
# Processing Record 47 of Set 9 | genhe
# Processing Record 48 of Set 9 | mount isa
# Processing Record 49 of Set 9 | uvira
# Processing Record 0 of Set 10 | shalqar
# Processing Record 1 of Set 10 | guanare
# Processing Record 2 of Set 10 | sedziszow
# Processing Record 3 of Set 10 | sant'antioco
# Processing Record 4 of Set 10 | qashyr
# Processing Record 5 of Set 10 | paradip garh
# Processing Record 6 of Set 10 | naracoorte
# Processing Record 7 of Set 10 | prado
# Processing Record 8 of Set 10 | chernyshevskiy
# Processing Record 9 of Set 10 | manokwari
# Processing Record 10 of Set 10 | nueva gerona
# Processing Record 11 of Set 10 | vallegrande
# Processing Record 12 of Set 10 | crescent city
# Processing Record 13 of Set 10 | peno
# Processing Record 14 of Set 10 | al kharijah
# Processing Record 15 of Set 10 | plastun
# Processing Record 16 of Set 10 | leava
# Processing Record 17 of Set 10 | patong
# Processing Record 18 of Set 10 | alice springs
# Processing Record 19 of Set 10 | tateyama
# Processing Record 20 of Set 10 | qamdo
# Processing Record 21 of Set 10 | mirganj
# Processing Record 22 of Set 10 | abra pampa
# Processing Record 23 of Set 10 | santiago de cao
# Processing Record 24 of Set 10 | essaouira
# Processing Record 25 of Set 10 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 26 of Set 10 | sibolga
# Processing Record 27 of Set 10 | dar naim
# City not found. Skipping...
# Processing Record 28 of Set 10 | charters towers
# Processing Record 29 of Set 10 | horta
# Processing Record 30 of Set 10 | south boston
# Processing Record 31 of Set 10 | san ignacio
# Processing Record 32 of Set 10 | ribadesella
# Processing Record 33 of Set 10 | nogliki
# Processing Record 34 of Set 10 | cidreira
# Processing Record 35 of Set 10 | susangerd
# Processing Record 36 of Set 10 | viedma
# Processing Record 37 of Set 10 | puerto baquerizo moreno
# Processing Record 38 of Set 10 | san nicolas de los arroyos
# Processing Record 39 of Set 10 | vernon
# Processing Record 40 of Set 10 | al bawiti
# Processing Record 41 of Set 10 | tvoroyri
# Processing Record 42 of Set 10 | nyaunglebin
# Processing Record 43 of Set 10 | tregunc
# Processing Record 44 of Set 10 | stephenville
# Processing Record 45 of Set 10 | dalandzadgad
# Processing Record 46 of Set 10 | san antonio de pale
# Processing Record 47 of Set 10 | kindu
# Processing Record 48 of Set 10 | sultanah
# Processing Record 49 of Set 10 | kill devil hills
# Processing Record 0 of Set 11 | gamboma
# Processing Record 1 of Set 11 | morehead city
# Processing Record 2 of Set 11 | minab
# Processing Record 3 of Set 11 | heihe
# Processing Record 4 of Set 11 | mizan teferi
# Processing Record 5 of Set 11 | agnibilekrou
# Processing Record 6 of Set 11 | velikiy ustyug
# Processing Record 7 of Set 11 | owando
# Processing Record 8 of Set 11 | nadi
# Processing Record 9 of Set 11 | mariel
# Processing Record 10 of Set 11 | kapit
# Processing Record 11 of Set 11 | pathein
# Processing Record 12 of Set 11 | tulun
# Processing Record 13 of Set 11 | narrabri
# Processing Record 14 of Set 11 | maputo
# Processing Record 15 of Set 11 | san sebastian de la gomera
# Processing Record 16 of Set 11 | vingt cinq
# City not found. Skipping...
# Processing Record 17 of Set 11 | shatsk
# Processing Record 18 of Set 11 | les avirons
# Processing Record 19 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 20 of Set 11 | loiza
# Processing Record 21 of Set 11 | saintes
# Processing Record 22 of Set 11 | orapa
# Processing Record 23 of Set 11 | rosario do sul
# Processing Record 24 of Set 11 | tucurui
# Processing Record 25 of Set 11 | pasuquin
# Processing Record 26 of Set 11 | khash
# Processing Record 27 of Set 11 | vilyuysk
# Processing Record 28 of Set 11 | kapsowar
# City not found. Skipping...
# Processing Record 29 of Set 11 | sabang
# Processing Record 30 of Set 11 | zhigalovo
# Processing Record 31 of Set 11 | khovd
# Processing Record 32 of Set 11 | sakaiminato
# Processing Record 33 of Set 11 | sonsorol village
# City not found. Skipping...
# Processing Record 34 of Set 11 | romanovka
# Processing Record 35 of Set 11 | nago
# Processing Record 36 of Set 11 | makassar
# Processing Record 37 of Set 11 | sao francisco do sul
# Processing Record 38 of Set 11 | qionghai
# Processing Record 39 of Set 11 | matamey
# Processing Record 40 of Set 11 | fort stockton
# Processing Record 41 of Set 11 | pucon
# Processing Record 42 of Set 11 | kasongo-lunda
# Processing Record 43 of Set 11 | pariaman
# Processing Record 44 of Set 11 | hell-ville
# Processing Record 45 of Set 11 | sakakah
# Processing Record 46 of Set 11 | fortaleza
# Processing Record 47 of Set 11 | rio gallegos
# Processing Record 48 of Set 11 | canton
# Processing Record 49 of Set 11 | belmonte
# Processing Record 0 of Set 12 | buritis
# Processing Record 1 of Set 12 | coahuayana de hidalgo
# Processing Record 2 of Set 12 | arteche
# Processing Record 3 of Set 12 | rukban
# City not found. Skipping...
# Processing Record 4 of Set 12 | nuku'alofa
# Processing Record 5 of Set 12 | shumerlya
# Processing Record 6 of Set 12 | teluknaga
# Processing Record 7 of Set 12 | novo aripuana
# Processing Record 8 of Set 12 | richards bay
# Processing Record 9 of Set 12 | suva
# Processing Record 10 of Set 12 | wenxing
# Processing Record 11 of Set 12 | subkhankulovo
# Processing Record 12 of Set 12 | kingston
# Processing Record 13 of Set 12 | vinh yen
# Processing Record 14 of Set 12 | kulhudhuffushi
# Processing Record 15 of Set 12 | atasu
# Processing Record 16 of Set 12 | bhamo
# Processing Record 17 of Set 12 | sambava
# Processing Record 18 of Set 12 | rikaze
# Processing Record 19 of Set 12 | burang
# Processing Record 20 of Set 12 | grand rapids
# Processing Record 21 of Set 12 | puerto ayacucho
# Processing Record 22 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 23 of Set 12 | whitby
# Processing Record 24 of Set 12 | katsuren-haebaru
# Processing Record 25 of Set 12 | porto novo
# Processing Record 26 of Set 12 | belyy yar
# Processing Record 27 of Set 12 | kuqa
# Processing Record 28 of Set 12 | chui
# Processing Record 29 of Set 12 | campbell river
# Processing Record 30 of Set 12 | briviesca
# Processing Record 31 of Set 12 | lucapa
# Processing Record 32 of Set 12 | duncan town
# City not found. Skipping...
# Processing Record 33 of Set 12 | luanda
# Processing Record 34 of Set 12 | baardheere
# Processing Record 35 of Set 12 | la passe
# Processing Record 36 of Set 12 | brisas de zicatela
# Processing Record 37 of Set 12 | kamiiso
# Processing Record 38 of Set 12 | kenora
# Processing Record 39 of Set 12 | vilcun
# Processing Record 40 of Set 12 | magong
# Processing Record 41 of Set 12 | paso de los toros
# Processing Record 42 of Set 12 | margate
# Processing Record 43 of Set 12 | puerto madryn
# Processing Record 44 of Set 12 | touros
# Processing Record 45 of Set 12 | smolensk
# Processing Record 46 of Set 12 | buala
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame - OK
city_data_df = pd.DataFrame(city_data)


# Show Record Count
city_data_df.count()
# Out:
# City          564
# Lat           564
# Lng           564
# Max Temp      564
# Humidity      564
# Cloudiness    564
# Wind Speed    564
# Country       564
# Date          564
# dtype: int64

# %%
# Convert the "City" column to title case
city_data_df['City'] = city_data_df['City'].str.title()
city_data_df['Date'] = pd.to_datetime(city_data_df['Date'], unit='s').dt.strftime('%Y-%m-%d')

# Display sample data
city_data_df.head()
# Out:
#            City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Olonkinbyen  70.9221  -8.7187    274.24        90         100       11.99
# 1   El Calafate -50.3408 -72.2768    270.56        64           0        2.59
# 2  Mbanza Kongo  -6.2670  14.2401    295.07        87         100        1.07
# 3   Egilsstadir  65.2653 -14.3948    276.10       100          75        1.54
# 4     Grytviken -54.2811 -36.5092    275.42        87          14        4.39
#
#   Country        Date
# 0      SJ  2024-05-06
# 1      AR  2024-05-06
# 2      AO  2024-05-06
# 3      IS  2024-05-06
# 4      GS  2024-05-06

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         Olonkinbyen  70.9221  -8.7187    274.24        90         100
# 1         El Calafate -50.3408 -72.2768    270.56        64           0
# 2        Mbanza Kongo  -6.2670  14.2401    295.07        87         100
# 3         Egilsstadir  65.2653 -14.3948    276.10       100          75
# 4           Grytviken -54.2811 -36.5092    275.42        87          14
#
#          Wind Speed Country        Date
# City_ID
# 0             11.99      SJ  2024-05-06
# 1              2.59      AR  2024-05-06
# 2              1.07      AO  2024-05-06
# 3              1.54      IS  2024-05-06
# 4              4.39      GS  2024-05-06

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o", edgecolors='black')

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o", edgecolors='black')

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o", edgecolors='black')

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o", edgecolors='black')

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
from scipy import stats
# Define a function to create Linear Regression plots
# Perform a linear regression on temperature vs. latitude
x_values = city_data_df["Lat"]
y_values = city_data_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
print(regress_values)
# Out:
# City_ID
# 0      282.435006
# 1      300.364297
# 2      293.847778
# 3      283.271390
# 4      300.946889
#           ...
# 559    285.324205
# 560    299.244801
# 561    293.689855
# 562    284.789163
# 563    294.125449
# Name: Lat, Length: 564, dtype: float64

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         Olonkinbyen  70.9221   -8.7187    274.24        90         100
# 3         Egilsstadir  65.2653  -14.3948    276.10       100          75
# 5              Aqadyr  48.2553   72.8483    277.82        72         100
# 7        Longyearbyen  78.2186   15.6401    269.06        68          75
# 9         Yellowknife  62.4560 -114.3525    287.27        55          40
#
#          Wind Speed Country        Date
# City_ID
# 0             11.99      SJ  2024-05-06
# 3              1.54      IS  2024-05-06
# 5              1.08      KZ  2024-05-06
# 7              1.54      SJ  2024-05-06
# 9              5.14      CA  2024-05-06

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 1                        El Calafate -50.3408  -72.2768    270.56        64
# 2                       Mbanza Kongo  -6.2670   14.2401    295.07        87
# 4                          Grytviken -54.2811  -36.5092    275.42        87
# 6                          Adamstown -25.0660 -130.1015    294.89        67
# 8        Edinburgh Of The Seven Seas -37.0676  -12.3116    286.50        64
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1                 0        2.59      AR  2024-05-06
# 2               100        1.07      AO  2024-05-06
# 4                14        4.39      GS  2024-05-06
# 6                65        8.65      PN  2024-05-06
# 8               100       13.31      SH  2024-05-06

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Label plot and annotate the line equation
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')

# Annotate the line equation within the plot - anchor to slope
plt.annotate(line_eq, (min(x_values) + 10, min(y_values) + 10), fontsize=15, color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.722547563579208

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Label plot and annotate the line equation
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')

# Annotate the line equation within the plot - anchor to slope
plt.annotate(line_eq, (min(x_values) + 10, min(y_values) + 10), fontsize=15, color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.619423507105442

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Label plot and annotate the line equation
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Humidity')

# Annotate the line equation within the plot - anchor to slope
plt.annotate(line_eq, (min(x_values) + 10, min(y_values) + 10), fontsize=15, color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.0047286661364249714

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Label plot and annotate the line equation
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Humidity')

# Annotate the line equation within the plot - anchor to slope
plt.annotate(line_eq, (min(x_values) + 10, min(y_values) + 10), fontsize=15, color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.10808840652870613

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Label plot and annotate the line equation
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

# Annotate the line equation within the plot - anchor to slope
plt.annotate(line_eq, (min(x_values) + 10, min(y_values) + 10), fontsize=15, color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.011205076722787808

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Label plot and annotate the line equation
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

# Annotate the line equation within the plot - anchor to slope
plt.annotate(line_eq, (min(x_values) + 10, min(y_values) + 10), fontsize=15, color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.03540320917543842

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Label plot and annotate the line equation
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

# Annotate the line equation within the plot - anchor to slope
plt.annotate(line_eq, (min(x_values) + 10, min(y_values) + 10), fontsize=15, color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.00026912615861870016

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Label plot and annotate the line equation
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

# Annotate the line equation within the plot - anchor to slope
plt.annotate(line_eq, (min(x_values) + 10, min(y_values) + 10), fontsize=15, color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.035960710115756744

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
